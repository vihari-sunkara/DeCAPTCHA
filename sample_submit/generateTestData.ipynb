# %%
import os
f_codes= open("codes.txt","a+")

# %%
i=1
for f in sorted(os.listdir("test")):
    print(f)
    f_codes.write(f+"\n")
    filename = "img"+str(i)+".png"
    os.rename("test/"+f,"test/"+filename)
    i+=1
f_codes.close()
# Out:
# AAA.png
# AAE.png
# AAGL.png
# AAQI.png
# AAR.png
# ABJG.png
# ABU.png
# ACA.png
# ACD.png
# ACF.png
# ACI.png
# ACKZ.png
# ACN.png
# ACW.png
# ACWT.png
# ADB.png
# ADTX.png
# ADVV.png
# ADY.png
# AEDC.png
# AEIK.png
# AFD.png
# AFLI.png
# AFU.png
# AGIA.png
# AGQ.png
# AGZF.png
# AHCD.png
# AHLD.png
# AHMC.png
# AING.png
# AIPO.png
# AISL.png
# AJGG.png
# AJMN.png
# AJOX.png
# ALBS.png
# ALZM.png
# AMG.png
# AMI.png
# AML.png
# ANDB.png
# ANHL.png
# ANJ.png
# ANMH.png
# ANVB.png
# APE.png
# APHK.png
# APQO.png
# APRQ.png
# AQLE.png
# AQO.png
# AQVU.png
# ARFQ.png
# ARI.png
# ARQ.png
# ARWT.png
# ASBH.png
# ASX.png
# ASXC.png
# ASXG.png
# ASYK.png
# ATK.png
# ATZ.png
# AUCS.png
# AUK.png
# AUYK.png
# AVEO.png
# AVFR.png
# AVR.png
# AVXS.png
# AWB.png
# AWI.png
# AWS.png
# AWVY.png
# AXAK.png
# AXAX.png
# AXL.png
# AXLM.png
# AYDQ.png
# AYF.png
# AYG.png
# AYMM.png
# AYSJ.png
# AZTP.png
# BAB.png
# BAOO.png
# BAS.png
# BAT.png
# BBTB.png
# BCEM.png
# BCQ.png
# BDFP.png
# BDI.png
# ...
